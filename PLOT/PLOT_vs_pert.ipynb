# %%
import pygmt

# %%
fig=pygmt.Figure()

# %%
fig.coast(region=[25, 40, -15, 4], shorelines="2/0.5p,darkgrey", resolution='i', water=None, projection="m0.2i")
fig.basemap(frame=['5f1', 'WSen'],  projection="m0.2i")
fig.show()

# %%
# ?fig.grdfilter()
# Out:
# Object `fig.grdfilter()` not found.
